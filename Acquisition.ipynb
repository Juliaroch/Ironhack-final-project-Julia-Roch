# %% [markdown]
# <a href="https://colab.research.google.com/github/Juliaroch/Ironhack-final-project-Julia-Roch/blob/master/Acquisition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Create the dataset with the 11 artists for my training
artists = pd.read_csv('/content/gdrive/My Drive/Final_project_data/artists.csv')
display(artists)
# Out:
#     id  ... paintings
# 0    0  ...       193
# 1    1  ...        88
# 2    2  ...        70
# 3    3  ...        73
# 4    4  ...       194
# 5    5  ...       139
# 6    6  ...        90
# 7    7  ...        99
# 8    8  ...       877
# 9    9  ...       117
# 10  10  ...       137
# 11  11  ...       126
# 12  12  ...       171
# 13  13  ...       439
# 14  14  ...       141
# 15  15  ...       336
# 16  16  ...       291
# 17  17  ...       120
# 18  18  ...        87
# 19  19  ...       328
# 20  20  ...       259
# 21  21  ...       134
# 22  22  ...       239
# 23  23  ...       119
# 24  24  ...       164
# 25  25  ...        55
# 26  26  ...       143
# 27  27  ...       128
# 28  28  ...       186
# 29  29  ...        81
# 30  30  ...       702
# 31  31  ...       262
# 32  32  ...       255
# 33  33  ...        81
# 34  34  ...        59
# 35  35  ...        91
# 36  36  ...        66
# 37  37  ...        67
# 38  38  ...        47
# 39  39  ...        31
# ...

# %%
#Filtering for the ones that have more than 239 paintings
data_artists = artists[artists['paintings'] >= 239].reset_index(drop=True)
display(data_artists)
# Out:
#     id  ... paintings
# 0    8  ...       877
# 1   13  ...       439
# 2   15  ...       336
# 3   16  ...       291
# 4   19  ...       328
# 5   20  ...       259
# 6   22  ...       239
# 7   30  ...       702
# 8   31  ...       262
# 9   32  ...       255
# 10  46  ...       311
#
# [11 rows x 8 columns]

# %%
#Saving our new dataframe with the 11 astists selected
data_artists.to_csv('/content/gdrive/My Drive/Final_project_data/data_artists.csv')
