# %% [markdown]
# <a href="https://colab.research.google.com/github/Juliaroch/Ironhack-final-project-Julia-Roch/blob/master/CNN_INCV3_FC130420train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
import matplotlib 
import matplotlib.pyplot as plt
import random 
import numpy as np
import tensorflow as tf
from sklearn import metrics
from sklearn.metrics import auc, roc_curve, roc_auc_score
import json
import simplejson as json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-b9c9c0fdbd63> in <module>()
#      10 from sklearn.metrics import auc, roc_curve, roc_auc_score
#      11 import json
# ---> 12 import simplejson as json
#
# ModuleNotFoundError: No module named 'simplejson'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from tensorflow.python.keras.applications.inception_v3 import InceptionV3
from tensorflow.python.keras.preprocessing import image
from tensorflow.python.keras.models import Model
from tensorflow.python.keras.optimizers import RMSprop, SGD
from tensorflow.python.keras.layers import Dense, GlobalAveragePooling2D
from keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import *
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Import the images from 11 artists I need for my training
images_dir = '/content/gdrive/My Drive/Final_project_data/resized_train_test'
data_artists = pd.read_csv('/content/gdrive/My Drive/Final_project_data/data_artists.csv')
artists_dirs = os.listdir(images_dir)
artists_top_name = data_artists['name'].str.replace(' ', '_').values

# See if all directories exist
for name in artists_top_name:
    if os.path.exists(os.path.join(images_dir, name)):
        print("Found -->", os.path.join(images_dir, name))
    else:
        print("Did not find -->", os.path.join(images_dir, name))
# Out:
# Found --> /content/gdrive/My Drive/Final_project_data/resized_train_test/Vincent_van_Gogh
# Found --> /content/gdrive/My Drive/Final_project_data/resized_train_test/Pablo_Picasso
# Found --> /content/gdrive/My Drive/Final_project_data/resized_train_test/Pierre-Auguste_Renoir
# Found --> /content/gdrive/My Drive/Final_project_data/resized_train_test/Francisco_Goya
# Found --> /content/gdrive/My Drive/Final_project_data/resized_train_test/Albrecht_Dürer
# Found --> /content/gdrive/My Drive/Final_project_data/resized_train_test/Alfred_Sisley
# Found --> /content/gdrive/My Drive/Final_project_data/resized_train_test/Marc_Chagall
# Found --> /content/gdrive/My Drive/Final_project_data/resized_train_test/Edgar_Degas
# Found --> /content/gdrive/My Drive/Final_project_data/resized_train_test/Rembrandt
# Found --> /content/gdrive/My Drive/Final_project_data/resized_train_test/Titian
# Found --> /content/gdrive/My Drive/Final_project_data/resized_train_test/Paul_Gauguin

# %%
#See if images have been imported correctly 
n = 5
fig, axes = plt.subplots(1, n, figsize=(20,10))

for i in range(n):
    random_artist = random.choice(artists_top_name)
    random_image = random.choice(os.listdir(os.path.join(images_dir, random_artist)))
    random_image_file = os.path.join(images_dir, random_artist, random_image)
    image = plt.imread(random_image_file)
    axes[i].imshow(image)
    axes[i].set_title("Artist: " + random_artist.replace('_', ' '))
    axes[i].axis('off')

plt.show()

# %%
#Train_test_split
batch_size = 16
train_input_shape = (128, 128, 3)
n_classes = artists_top_name.shape[0]

train_datagen=ImageDataGenerator(validation_split=0.1,rescale=1./255.,horizontal_flip=True,vertical_flip=True)
                                 
train_generator=train_datagen.flow_from_directory(directory=images_dir,class_mode='categorical',target_size=train_input_shape[0:2],batch_size=batch_size,subset="training",shuffle=True,classes=artists_top_name.tolist())
                                                   
valid_generator=train_datagen.flow_from_directory(directory=images_dir,class_mode='categorical',target_size=train_input_shape[0:2],batch_size=batch_size,subset="validation",shuffle=True,classes=artists_top_name.tolist())

STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
print("Total number of batches =", STEP_SIZE_TRAIN, "and", STEP_SIZE_VALID)
# Out:
# Found 2384 images belonging to 11 classes.
# Found 262 images belonging to 11 classes.
# Total number of batches = 149 and 16

# %%
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=train_input_shape)

# %%
# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(1024, activation='relu')(x)
# and a logistic layer -- let's say we have n_classes classes
output = Dense(n_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# %%
# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
for layer in base_model.layers:
    layer.trainable = False

#without freezing layers
#for layer in base_model.layers:
    #layer.trainable = True

# compile the model (should be done *after* setting layers to non-trainable)

optimizer = tf.keras.optimizers.RMSprop(lr=0.001)

model.compile(optimizer=optimizer, loss='categorical_crossentropy',metrics=['accuracy'])

# %%
n_epoch = 4

early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1, mode='auto', restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, mode='auto')

# %%
history1 = model.fit_generator(generator=train_generator, steps_per_epoch=STEP_SIZE_TRAIN, validation_data=valid_generator, validation_steps=STEP_SIZE_VALID, epochs=n_epoch, shuffle=True, verbose=1, callbacks=[reduce_lr], use_multiprocessing=True, workers=16)
# Out:
# WARNING:tensorflow:From <ipython-input-11-ec5325545f09>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# Epoch 1/4
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - ETA: 0s - loss: 1.2300 - accuracy: 0.8687WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 15s 102ms/step - loss: 1.2300 - accuracy: 0.8687 - val_loss: 3.3827 - val_accuracy: 0.1875 - lr: 0.0010
# Epoch 2/4
# 149/149 [==============================] - ETA: 0s - loss: 0.4381 - accuracy: 0.9165WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 14s 96ms/step - loss: 0.4381 - accuracy: 0.9165 - val_loss: 3.0529 - val_accuracy: 0.2500 - lr: 0.0010
# Epoch 3/4
# 149/149 [==============================] - ETA: 0s - loss: 0.4599 - accuracy: 0.9107WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 14s 94ms/step - loss: 0.4599 - accuracy: 0.9107 - val_loss: 2.9896 - val_accuracy: 0.3242 - lr: 0.0010
# Epoch 4/4
# 149/149 [==============================] - ETA: 0s - loss: 0.3623 - accuracy: 0.9140WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 13s 89ms/step - loss: 0.3623 - accuracy: 0.9140 - val_loss: 2.8956 - val_accuracy: 0.3750 - lr: 0.0010

# %%
#for layer in model.layers[:249]:
 #  layer.trainable = False

#for layer in model.layers[249:]:
 #  layer.trainable = True

for layer in model.layers[:172]:
   layer.trainable = False

for layer in model.layers[172:]:
   layer.trainable = True

tf.keras.optimizers.SGD(lr=0.001, momentum=0.9)

model.compile(optimizer='SGD', loss='categorical_crossentropy',metrics=['accuracy'])

n_epoch = 28
history2 = model.fit_generator(generator=train_generator, steps_per_epoch=STEP_SIZE_TRAIN, validation_data=valid_generator, validation_steps=STEP_SIZE_VALID, epochs=n_epoch, shuffle=True, verbose=1, callbacks=[reduce_lr, early_stop], use_multiprocessing=True, workers=16)
# Out:
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# Epoch 1/28
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - ETA: 0s - loss: 0.2243 - accuracy: 0.9425WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 25s 168ms/step - loss: 0.2243 - accuracy: 0.9425 - val_loss: 1.9583 - val_accuracy: 0.2695 - lr: 0.0100
# Epoch 2/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.9593WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 28s 188ms/step - loss: 0.1477 - accuracy: 0.9593 - val_loss: 1.3802 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 3/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1331 - accuracy: 0.9631WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 27s 181ms/step - loss: 0.1331 - accuracy: 0.9631 - val_loss: 1.7323 - val_accuracy: 0.3750 - lr: 0.0100
# Epoch 4/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.9660WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 27s 180ms/step - loss: 0.1142 - accuracy: 0.9660 - val_loss: 2.5810 - val_accuracy: 0.2031 - lr: 0.0100
# Epoch 5/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1227 - accuracy: 0.9652WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 26s 174ms/step - loss: 0.1227 - accuracy: 0.9652 - val_loss: 1.5004 - val_accuracy: 0.4961 - lr: 0.0100
# Epoch 6/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.9660WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 26s 174ms/step - loss: 0.1210 - accuracy: 0.9660 - val_loss: 1.1898 - val_accuracy: 0.5586 - lr: 0.0100
# Epoch 7/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1432 - accuracy: 0.9581WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 24s 164ms/step - loss: 0.1432 - accuracy: 0.9581 - val_loss: 1.4894 - val_accuracy: 0.5469 - lr: 0.0100
# Epoch 8/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1144 - accuracy: 0.9677WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 25s 165ms/step - loss: 0.1144 - accuracy: 0.9677 - val_loss: 2.1394 - val_accuracy: 0.3750 - lr: 0.0100
# Epoch 9/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9681WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 24s 163ms/step - loss: 0.1100 - accuracy: 0.9681 - val_loss: 1.4292 - val_accuracy: 0.5000 - lr: 0.0100
# Epoch 10/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9597WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 24s 163ms/step - loss: 0.1272 - accuracy: 0.9597 - val_loss: 1.5643 - val_accuracy: 0.4414 - lr: 0.0100
# Epoch 11/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9652WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 24s 164ms/step - loss: 0.1172 - accuracy: 0.9652 - val_loss: 1.1185 - val_accuracy: 0.6289 - lr: 0.0100
# Epoch 12/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9652WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 24s 163ms/step - loss: 0.1102 - accuracy: 0.9652 - val_loss: 1.2475 - val_accuracy: 0.5610 - lr: 0.0100
# Epoch 13/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 0.9711WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 24s 158ms/step - loss: 0.1057 - accuracy: 0.9711 - val_loss: 1.8571 - val_accuracy: 0.3679 - lr: 0.0100
# Epoch 14/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1128 - accuracy: 0.9673WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 26s 175ms/step - loss: 0.1128 - accuracy: 0.9673 - val_loss: 1.6468 - val_accuracy: 0.4375 - lr: 0.0100
# Epoch 15/28
# 149/149 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9719WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 26s 172ms/step - loss: 0.0994 - accuracy: 0.9719 - val_loss: 1.8544 - val_accuracy: 0.3945 - lr: 0.0100
# Epoch 16/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1007 - accuracy: 0.9702WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 149/149 [==============================] - 24s 162ms/step - loss: 0.1007 - accuracy: 0.9702 - val_loss: 1.3469 - val_accuracy: 0.5039 - lr: 0.0100
# Epoch 17/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1482 - accuracy: 0.9715WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 25s 167ms/step - loss: 0.1482 - accuracy: 0.9715 - val_loss: 1.6860 - val_accuracy: 0.4922 - lr: 1.0000e-03
# Epoch 18/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9736WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 25s 168ms/step - loss: 0.1407 - accuracy: 0.9736 - val_loss: 2.5774 - val_accuracy: 0.3359 - lr: 1.0000e-03
# Epoch 19/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9736WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 25s 166ms/step - loss: 0.1313 - accuracy: 0.9736 - val_loss: 0.7482 - val_accuracy: 0.6836 - lr: 1.0000e-03
# Epoch 20/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9706WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 25s 171ms/step - loss: 0.1298 - accuracy: 0.9706 - val_loss: 1.2275 - val_accuracy: 0.6914 - lr: 1.0000e-03
# Epoch 21/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9803WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 26s 175ms/step - loss: 0.1037 - accuracy: 0.9803 - val_loss: 0.6417 - val_accuracy: 0.6797 - lr: 1.0000e-03
# Epoch 22/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9744WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 26s 177ms/step - loss: 0.1205 - accuracy: 0.9744 - val_loss: 1.3144 - val_accuracy: 0.5000 - lr: 1.0000e-03
# Epoch 23/28
# 149/149 [==============================] - ETA: 0s - loss: 0.0900 - accuracy: 0.9820WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 27s 179ms/step - loss: 0.0900 - accuracy: 0.9820 - val_loss: 1.5644 - val_accuracy: 0.5039 - lr: 1.0000e-03
# Epoch 24/28
# 149/149 [==============================] - ETA: 0s - loss: 0.0974 - accuracy: 0.9794WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 27s 181ms/step - loss: 0.0974 - accuracy: 0.9794 - val_loss: 1.5173 - val_accuracy: 0.5078 - lr: 1.0000e-03
# Epoch 25/28
# 149/149 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9786WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 27s 179ms/step - loss: 0.0938 - accuracy: 0.9786 - val_loss: 1.2422 - val_accuracy: 0.6250 - lr: 1.0000e-03
# Epoch 26/28
# 149/149 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9757WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 149/149 [==============================] - 29s 195ms/step - loss: 0.1135 - accuracy: 0.9757 - val_loss: 1.1128 - val_accuracy: 0.4375 - lr: 1.0000e-03
# Epoch 27/28
# 149/149 [==============================] - ETA: 0s - loss: 0.4090 - accuracy: 0.8993WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 27s 181ms/step - loss: 0.4090 - accuracy: 0.8993 - val_loss: 1.6395 - val_accuracy: 0.6250 - lr: 1.0000e-04
# Epoch 28/28
# 149/149 [==============================] - ETA: 0s - loss: 0.3707 - accuracy: 0.9077WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 149/149 [==============================] - 28s 188ms/step - loss: 0.3707 - accuracy: 0.9077 - val_loss: 1.5151 - val_accuracy: 0.5703 - lr: 1.0000e-04

# %%
#score = model.evaluate_generator(train_generator, verbose=1)
#print("Prediction accuracy on train data =", score[1])

# %%
#score = model.evaluate_generator(valid_generator, verbose=1)
#print("Prediction accuracy on CV data =", score[1])

# %%
# serialize weights to HDF5 & model to json
model.save_weights("/content/gdrive/My Drive/Final_project_data/WI3-FC-34TE-130420v3.h5")
print("Saved model to disk")
model_json = model.to_json()
with open("/content/gdrive/My Drive/Final_project_data/model.json", "w") as json_file:
    json_file.write(model_json)
# Out:
# Saved model to disk

# %%
 # Classification report and confusion matrix
from sklearn.metrics import *
import seaborn as sns

tick_labels = artists_top_name.tolist()

def showClassficationReport_Generator(model, valid_generator, STEP_SIZE_VALID):
    # Loop on each generator batch and predict
    y_pred, y_true = [], []
    for i in range(STEP_SIZE_VALID):
        (X,y) = next(valid_generator)
        y_pred.append(model.predict(X))
        y_true.append(y)
    
    # Create a flat list for y_true and y_pred
    y_pred = [subresult for result in y_pred for subresult in result]
    y_true = [subresult for result in y_true for subresult in result]
    
    # Update Truth vector based on argmax
    y_true = np.argmax(y_true, axis=1)
    y_true = np.asarray(y_true).ravel()
    
    # Update Prediction vector based on argmax
    y_pred = np.argmax(y_pred, axis=1)
    y_pred = np.asarray(y_pred).ravel()
    
    # Confusion Matrix
    fig, ax = plt.subplots(figsize=(10,10))
    conf_matrix = confusion_matrix(y_true, y_pred, labels=np.arange(n_classes))
    conf_matrix = conf_matrix/np.sum(conf_matrix, axis=1)
    sns.heatmap(conf_matrix, annot=True, fmt=".2f", square=True, cbar=False, 
                cmap=plt.cm.jet, xticklabels=tick_labels, yticklabels=tick_labels,
                ax=ax)
    ax.set_ylabel('Actual')
    ax.set_xlabel('Predicted')
    ax.set_title('Confusion Matrix')
    plt.show()
    
    print('Classification Report:')
    print(classification_report(y_true, y_pred, labels=np.arange(n_classes), target_names=artists_top_name.tolist()))

    return y_pred, y_true

y_pred, y_true = showClassficationReport_Generator(model, valid_generator, STEP_SIZE_VALID)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Classification Report:
#                        precision    recall  f1-score   support
#
#      Vincent_van_Gogh       0.52      0.61      0.56        23
#         Pablo_Picasso       0.67      0.62      0.64        26
# Pierre-Auguste_Renoir       0.75      0.50      0.60        24
#        Francisco_Goya       0.52      0.52      0.52        23
#        Albrecht_Dürer       0.81      0.91      0.86        23
#         Alfred_Sisley       0.78      0.64      0.70        22
#          Marc_Chagall       0.60      0.63      0.62        19
#           Edgar_Degas       0.58      0.67      0.62        27
#             Rembrandt       0.54      0.74      0.62        19
#                Titian       0.47      0.53      0.50        15
#          Paul_Gauguin       0.56      0.40      0.47        25
#
#              accuracy                           0.61       246
#             macro avg       0.62      0.61      0.61       246
#          weighted avg       0.62      0.61      0.61       246

# %%
y_pred
y_true
model.save('/content/gdrive/My Drive/Final_project_data/MI3-FC-34TE-130420v3.h5')

# %%
#Calculating roc and auc curves
y_true = y_true # true labels
y_probas = y_pred # predicted results
fpr, tpr, thresholds = metrics.roc_curve(y_true, y_probas, pos_label=0)

# Print ROC curve
plt.plot(fpr,tpr)
plt.show() 

# Print AUC
auc = np.trapz(tpr,fpr)
print('AUC:', auc)
# Out:
# AUC: 0.22626242932345483

# %%
# serialize model to JSON
model_json = model.to_json()
with open("/content/gdrive/My Drive/Final_project_data/JI3-FC-34TE-130420v3.json", "w") as json_file:
    json_file.write(json.dumps(json.loads(model_json), indent=4))
#json_config = model.to_json("/content/gdrive/My Drive/Final_project_data/JI3-FC-34TE-130420v3.json")

# %%
#Calculating roc and auc scores
y_pred_keras = y_pred
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_true, y_pred_keras, pos_label=0)

auc_keras = auc(fpr_keras, tpr_keras)
print(fpr_keras, tpr_keras, thresholds_keras)
print(auc_keras)

# %%
roc_auc_score(y_true, y_pred, multi_class='ovo')
